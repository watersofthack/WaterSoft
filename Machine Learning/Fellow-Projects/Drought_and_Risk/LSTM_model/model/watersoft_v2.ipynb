# %%
# !git clone https://github.com/neuralhydrology/neuralhydrology.git
# %cd neuralhydrology
# Out:
# Cloning into 'neuralhydrology'...
# remote: Enumerating objects: 2409, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 2409 (delta 20), reused 9 (delta 9), pack-reused 2371 (from 3)
# Receiving objects: 100% (2409/2409), 11.61 MiB | 18.14 MiB/s, done.
# Resolving deltas: 100% (1516/1516), done.
# /home/jovyan/neuralhydrology

# %%
# !pip install -e .
# Out:
# Obtaining file:///home/jovyan/neuralhydrology
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 10.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.4 MB/s eta 0:00:000:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 560.0 kB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 15.2 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 544.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 332.7 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 9.3 MB/s eta 0:00:000:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 682.0 kB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...

# %%
cd
# Out:
# /home/jovyan

# %%
cd watersoft
# Out:
# /home/jovyan/watersoft

# %%
cd Model
# Out:
# /home/jovyan/watersoft/Model

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 989.6 kB/s eta 0:00:000:0100:01
# ...

# %%
pip install netCDF4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 29.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.7 MB/s eta 0:00:000:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m neuralhydrology.nh_run train --config-file watersoft/Model/basins_static.yml
# Out:
# 2025-08-07 18:57:35,264: Logging to /home/jovyan/watersoft/results_LSTM_v3/WaterSoft_0708_185735/output.log initialized.
# 2025-08-07 18:57:35,264: ### Folder structure created at /home/jovyan/watersoft/results_LSTM_v3/WaterSoft_0708_185735
# 2025-08-07 18:57:35,264: ### Run configurations for WaterSoft
# 2025-08-07 18:57:35,264: experiment_name: WaterSoft
# 2025-08-07 18:57:35,264: run_dir: /home/jovyan/watersoft/results_LSTM_v3/WaterSoft_0708_185735
# 2025-08-07 18:57:35,264: train_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 18:57:35,264: validation_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 18:57:35,264: test_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 18:57:35,264: train_start_date: 1980-01-01 00:00:00
# 2025-08-07 18:57:35,264: train_end_date: 2010-12-31 00:00:00
# 2025-08-07 18:57:35,264: validation_start_date: 2011-01-01 00:00:00
# 2025-08-07 18:57:35,264: validation_end_date: 2019-12-31 00:00:00
# ...

# %%
# !python -m neuralhydrology.nh_run evaluate --run-dir watersoft/results_LSTM_v3/WaterSoft_0708_185735
# Out:
# 2025-08-07 19:35:47,514: Logging to watersoft/results_LSTM_v3/WaterSoft_0708_185735/output.log initialized.
# 2025-08-07 19:35:48,336: Using the model weights from watersoft/results_LSTM_v3/WaterSoft_0708_185735/model_epoch100.pt
# ...
# # Evaluation: 100%|█████████████████████████████| 24/24 [00:03<00:00,  6.66it/s]
# 2025-08-07 19:35:51,945: Stored metrics at watersoft/results_LSTM_v3/WaterSoft_0708_185735/test/model_epoch100/test_metrics.csv
# 2025-08-07 19:35:51,950: Stored results at watersoft/results_LSTM_v3/WaterSoft_0708_185735/test/model_epoch100/test_results.p

# %%
# !python optuna_static_v2.py
# Out:
# Starting hyperparameter tuning...
# [I 2025-08-07 19:47:12,747] A new study created in memory with name: no-name-2761d8c1-bca4-4494-a987-5a5902961902
# [2025-08-07T19:47:12.756797] Starting Trial 0: lr6.1e-05_drop0.06_hs160_bs64
# 2025-08-07 19:47:15,601: Logging to /home/jovyan/watersoft/optuna_results_v3/lr6.1e-05_drop0.06_hs160_bs64/optuna_trial_0_0708_194715/output.log initialized.
# 2025-08-07 19:47:15,601: ### Folder structure created at /home/jovyan/watersoft/optuna_results_v3/lr6.1e-05_drop0.06_hs160_bs64/optuna_trial_0_0708_194715
# 2025-08-07 19:47:15,601: ### Run configurations for optuna_trial_0
# 2025-08-07 19:47:15,601: batch_size: 64
# 2025-08-07 19:47:15,601: clip_gradient_norm: 1
# 2025-08-07 19:47:15,601: data_dir: /home/jovyan/watersoft/Data
# 2025-08-07 19:47:15,601: dataset: generic
# 2025-08-07 19:47:15,601: device: cuda:0
# 2025-08-07 19:47:15,601: dynamic_inputs: ['prcp', 'tmax']
# 2025-08-07 19:47:15,601: epochs: 50
# ...

# %%
# !python -m neuralhydrology.nh_run train --config-file watersoft/Model/basins_static-Copy1.yml

# %%
# !python -m neuralhydrology.nh_run train --config-file watersoft/Model/basins_static-Copy1.yml
# Out:
# 2025-08-07 22:51:26,084: Logging to /home/jovyan/watersoft/results_LSTM_no_static/WaterSoft_0708_225126/output.log initialized.
# 2025-08-07 22:51:26,084: ### Folder structure created at /home/jovyan/watersoft/results_LSTM_no_static/WaterSoft_0708_225126
# 2025-08-07 22:51:26,084: ### Run configurations for WaterSoft
# 2025-08-07 22:51:26,084: experiment_name: WaterSoft
# 2025-08-07 22:51:26,084: run_dir: /home/jovyan/watersoft/results_LSTM_no_static/WaterSoft_0708_225126
# 2025-08-07 22:51:26,084: train_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 22:51:26,084: validation_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 22:51:26,084: test_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 22:51:26,084: train_start_date: 1980-01-01 00:00:00
# 2025-08-07 22:51:26,084: train_end_date: 2010-12-31 00:00:00
# 2025-08-07 22:51:26,084: validation_start_date: 2011-01-01 00:00:00
# ...

# %%
# !python -m neuralhydrology.nh_run evaluate --run-dir watersoft/results_LSTM_no_static/WaterSoft_0708_225126
# Out:
# 2025-08-07 23:09:46,889: Logging to watersoft/results_LSTM_no_static/WaterSoft_0708_225126/output.log initialized.
# 2025-08-07 23:09:47,509: Using the model weights from watersoft/results_LSTM_no_static/WaterSoft_0708_225126/model_epoch050.pt
# ...
# # Evaluation: 100%|█████████████████████████████| 24/24 [00:02<00:00,  9.20it/s]
# 2025-08-07 23:09:50,124: Stored metrics at watersoft/results_LSTM_no_static/WaterSoft_0708_225126/test/model_epoch050/test_metrics.csv
# 2025-08-07 23:09:50,129: Stored results at watersoft/results_LSTM_no_static/WaterSoft_0708_225126/test/model_epoch050/test_results.p

# %%
# !python -m neuralhydrology.nh_run train --config-file watersoft/Model/basins_static-Copy1.yml
# Out:
# 2025-08-07 23:11:45,103: Logging to /home/jovyan/watersoft/results_LSTM_no_static/WaterSoft_0708_231145/output.log initialized.
# 2025-08-07 23:11:45,103: ### Folder structure created at /home/jovyan/watersoft/results_LSTM_no_static/WaterSoft_0708_231145
# 2025-08-07 23:11:45,103: ### Run configurations for WaterSoft
# 2025-08-07 23:11:45,103: experiment_name: WaterSoft
# 2025-08-07 23:11:45,103: run_dir: /home/jovyan/watersoft/results_LSTM_no_static/WaterSoft_0708_231145
# 2025-08-07 23:11:45,103: train_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 23:11:45,103: validation_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 23:11:45,103: test_basin_file: /home/jovyan/watersoft/Model/basin_list.txt
# 2025-08-07 23:11:45,103: train_start_date: 1980-01-01 00:00:00
# 2025-08-07 23:11:45,103: train_end_date: 2010-12-31 00:00:00
# 2025-08-07 23:11:45,103: validation_start_date: 2011-01-01 00:00:00
# ...

# %%
# !python -m neuralhydrology.nh_run evaluate --run-dir watersoft/results_LSTM_no_static/WaterSoft_0708_231145
# Out:
# 2025-08-07 23:40:17,099: Logging to watersoft/results_LSTM_no_static/WaterSoft_0708_231145/output.log initialized.
# 2025-08-07 23:40:17,719: Using the model weights from watersoft/results_LSTM_no_static/WaterSoft_0708_231145/model_epoch100.pt
# ...
# # Evaluation: 100%|█████████████████████████████| 24/24 [00:02<00:00,  8.68it/s]
# 2025-08-07 23:40:20,489: Stored metrics at watersoft/results_LSTM_no_static/WaterSoft_0708_231145/test/model_epoch100/test_metrics.csv
# 2025-08-07 23:40:20,495: Stored results at watersoft/results_LSTM_no_static/WaterSoft_0708_231145/test/model_epoch100/test_results.p
